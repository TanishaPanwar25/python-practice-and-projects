# %% [markdown]
# #  Second Pandas prectise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Pokemon.csv")   
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Question 1
# How many Pokemons exist with an Attack value greater than 150?
# Find all the pokemons with an Attack value greater than 150 and enter the quantity.
number=df.loc[df["Attack"]>150].shape;
#df.query("Attack>150")
sns.boxplot(data=df,x="Attack")
# Out:
# <Axes: xlabel='Attack'>

# %%
# Question 2 (Code Validated)
# Select all pokemons with a Speed of 10 or less
# Use filtering to select those "slow" Pokemons with a Speed value of 10 or less.
# Store your results in the variable slow_pokemons_df.
slow_pokemons_df=df.query("Speed<=10")
slow_pokemons_df
s=df.loc[df["Speed"]<=10]
sns.boxplot(data=df,x="Speed")
s
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
# Question 3
# How many Pokemons have a Sp. Def value of 25 or less?
# The Sp. Def value indicates the defense power of a pokemon against Special abilities.
# How many pokemons have a value of 25 or less?
n=df.loc[df["Sp. Def"]<=25].shape[0]
#or
m=(df["Sp. Def"] <= 25).sum()
m
# Out:
# np.int64(18)

# %%
# Question 4 (Code Validated)
# Select all the Legendary pokemons
# Select only pokemons that are Legendary and store the result in the variable legendary_df.
legendary_df=df.loc[df["Legendary"]==True]
legendary_df
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
# Question 5
# Find the outlier
# Take a look at the scatterplot that correlates pokemons Attack and Defense.
# What's the name of the pokemon that is a clear outlier
# (strong Defense, but very low Attack)?
ax=sns.scatterplot(data=df,x="Defense",y="Attack")
ax.annotate(
    "who's this guys ",xy=(228,10),xytext=(150,10),color="orange",
arrowprops=dict(arrowstyle='->',color='red')

)


df.sort_values(by=["Defense","Attack"],ascending=[False,True])[["Name","Defense","Attack"]]
# Out:
#                     Name  Defense  Attack
# 230              Shuckle      230      10
# 224  SteelixMega Steelix      230     125
# 333    AggronMega Aggron      230     140
# 223              Steelix      200      85
# 414             Regirock      200     100
# ..                   ...      ...     ...
# 257             Smoochum       15      30
# 186                Pichu       15      40
# 261              Blissey       10      10
# 121              Chansey        5       5
# 488              Happiny        5       5
#
# [800 rows x 3 columns]

# %%
# Question 6
# How many Fire-Flying Pokemons are there?
# How many pokemons are of:

# Type 1 → Fire

# Type 2 → Flying
(
(df["Type 1"]=="Fire")&
(df["Type 2"]=="Flying")
).sum()
# Out:
# np.int64(6)

# %%
df.query("`Type 1`=='Fire' & `Type 2`=='Flying' ")
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
# Question 7

# How many 'Poison' pokemons are across both types?
# How many pokemons exist that are of type Poison in either Type 1 or Type 2?
df.query("`Type 1`=='Poison' or `Type 2`=='Poison' ").shape[0]
# Out:
# 62

# %%
((df['Type 1'] =='Poison') | (df['Type 2'] =='Poison')).sum()
# Out:
# np.int64(62)

# %%
# Question 8

# What pokemon of Type 1 Ice has the strongest defense?
# Enter its name below.
df.loc[df['Type 1']=="Ice","Defense"].max()
# Out:
# np.int64(184)

# %%
df.loc[
    (df['Type 1']=="Ice")&
    (df["Defense"]==df.loc[df['Type 1']=="Ice","Defense"].max())
]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 789  713  Avalugg    Ice    NaN    514  95     117      184       44       46
#
#      Speed  Generation  Legendary
# 789     28           6      False

# %%
df[df["Type 1"]=="Ice"].sort_values(by="Defense",ascending=False)
# Out:
#        #               Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 789  713            Avalugg    Ice      NaN    514   95     117      184
# 522  471            Glaceon    Ice      NaN    525   65      60      110
# 156  144           Articuno    Ice   Flying    580   90      85      100
# 415  378             Regice    Ice      NaN    580   80      50      100
# 400  365            Walrein    Ice    Water    530  110      80       90
# 645  584          Vanilluxe    Ice      NaN    535   71      95       85
# 788  712           Bergmite    Ice      NaN    304   55      69       85
# 239  221          Piloswine    Ice   Ground    450  100     100       80
# 675  614            Beartic    Ice      NaN    485   95     110       80
# 396  362             Glalie    Ice      NaN    480   80      80       80
# 524  473          Mamoswine    Ice   Ground    530  110     130       80
# 397  362  GlalieMega Glalie    Ice      NaN    580   80     120       80
# ...

# %%
# Question 9

# What's the most common type of Legendary Pokemons?
# What's the most common Type 1 for legendary pokemons?

df.loc[df["Legendary"],"Type 1"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type 1'>

# %%
# Question 10

# What's the most powerful pokemon from the first 3 generations, of type Water?
# Find the pokemon with the highest Total
# (from Generation 1–3 and Type Water).

df.loc[
    (df['Type 1'] == 'Water') &
    df['Generation'].isin([1,2,3])
].sort_values(by='Total',ascending=False)

#df['Genertion'].isin([1,2,3]).sum()
# Out:
#        #                     Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 422  382      KyogrePrimal Kyogre  Water     NaN    770  100     150       90
# 421  382                   Kyogre  Water     NaN    670  100     100       90
# 141  130    GyaradosMega Gyarados  Water    Dark    640   95     155      109
# 283  260    SwampertMega Swampert  Water  Ground    635  100     150      110
# 12     9  BlastoiseMega Blastoise  Water     NaN    630   79     103      120
# ..   ...                      ...    ...     ...    ...  ...     ...      ...
# 198  183                   Marill  Water   Fairy    250   70      20       50
# 293  270                    Lotad  Water   Grass    220   40      30       30
# 209  194                   Wooper  Water  Ground    210   55      45       45
# 139  129                 Magikarp  Water     NaN    200   20      10       55
# 381  349                   Feebas  Water     NaN    200   20      15       20
#
# ...

# %%
# Question 11

# What's the most powerful Dragon from the last two generations?
# Find the pokemon with the highest Total
# (Type Dragon in either Type 1 or Type 2, from last two generations).
df['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
df.loc[
   ( (df['Type 1']=='Dragon') |
    (df['Type 2']=='Dragon')
   )&
    (df['Generation'].isin({5,6}))
].sort_values(by="Total",ascending=False)
# Out:
#        #                Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# 712  646  KyuremWhite Kyurem  Dragon       Ice    700  125     120       90
# 711  646  KyuremBlack Kyurem  Dragon       Ice    700  125     170      100
# 707  644              Zekrom  Dragon  Electric    680  100     150      120
# 706  643            Reshiram  Dragon      Fire    680  100     120      100
# 710  646              Kyurem  Dragon       Ice    660  125     130       90
# 776  706              Goodra  Dragon       NaN    600   90     100       70
# 696  635           Hydreigon    Dark    Dragon    600   92     105       90
# 794  718    Zygarde50% Forme  Dragon    Ground    600  108     100      121
# 673  612             Haxorus  Dragon       NaN    540   76     147       90
# 791  715             Noivern  Flying    Dragon    535   85      70       80
# 767  697           Tyrantrum    Rock    Dragon    521   82     121      119
# ...

# %%
# Question 12 (Code Validated)

# Select most powerful Fire-type pokemons
# Select all pokemons that have:

# Attack value above 100

# Type 1 = Fire
# (ignore Type 2)

df.loc[(df["Type 1"] =="Fire") &
    (df["Attack"] >100)
    ].sort_values(by="Total",
                 ascending=False)
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 799  721                  Volcanion   Fire     Water    600   80     110
# 263  244                      Entei   Fire       NaN    580  115     115
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 147  136                    Flareon   Fire       NaN    525   65     130
# ...

# %%
d=df.query("Attack >100 & `Type 1`=='Fire'")
d
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 147  136                    Flareon   Fire       NaN    525   65     130
# 263  244                      Entei   Fire       NaN    580  115     115
# 270  250                      Ho-oh   Fire    Flying    680  106     130
# 278  257                   Blaziken   Fire  Fighting    530   80     120
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80     160
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70     120
# 437  392                  Infernape   Fire  Fighting    534   76     104
# 559  500                     Emboar   Fire  Fighting    528  110     123
# 615  555    DarmanitanStandard Mode   Fire       NaN    480  105     140
# ...

# %%
# Question 13 (Code Validated)

# Select all Water-type, Flying-type pokemons
# Select pokemons with:

# Type 1 = Water

# Type 2 = Flying

# Store results in water_flying_df.

water_flying_df=df.query("`Type 1`=='Water' and `Type 2` == 'Flying'")
water_flying_df
# Out:
#        #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 140  130  Gyarados  Water  Flying    540  95     125       79       60
# 244  226   Mantine  Water  Flying    465  65      40       70       80
# 301  278   Wingull  Water  Flying    270  40      30       30       55
# 302  279  Pelipper  Water  Flying    430  60      50      100       85
# 508  458   Mantyke  Water  Flying    345  45      20       50       60
# 641  580  Ducklett  Water  Flying    305  62      44       50       44
# 642  581    Swanna  Water  Flying    473  75      87       63       87
#
#      Sp. Def  Speed  Generation  Legendary
# 140      100     81           1      False
# 244      140     70           2      False
# 301       30     85           3      False
# 302       70     65           3      False
# 508      120     50           4      False
# 641       50     55           5      False
# 642       63     98           5      False

# %%
df.loc[
    (df["Type 1"]=="Water") &
    (df["Type 2"] == "Flying")
]
# Out:
#        #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 140  130  Gyarados  Water  Flying    540  95     125       79       60
# 244  226   Mantine  Water  Flying    465  65      40       70       80
# 301  278   Wingull  Water  Flying    270  40      30       30       55
# 302  279  Pelipper  Water  Flying    430  60      50      100       85
# 508  458   Mantyke  Water  Flying    345  45      20       50       60
# 641  580  Ducklett  Water  Flying    305  62      44       50       44
# 642  581    Swanna  Water  Flying    473  75      87       63       87
#
#      Sp. Def  Speed  Generation  Legendary
# 140      100     81           1      False
# 244      140     70           2      False
# 301       30     85           3      False
# 302       70     65           3      False
# 508      120     50           4      False
# 641       50     55           5      False
# 642       63     98           5      False

# %%
# Question 14 (Code Validated)
# Select specific columns of Legendary pokemons of type Fire
# Select Legendary pokemons with:
# Type 1 = Fire
# Only keep columns:
# Name
# Attack
# Generation
# Store results in legendary_fire_df.
lengendary_fire_df = df.loc[
    (df["Type 1"] == "Fire") & df['Legendary'],["Name","Attack","Generation"]
]
lengendary_fire_df


#df.loc[
(conditions for index),
(columns)
]
# Out:
#           Name  Attack  Generation
# 158    Moltres     100           1
# 263      Entei     115           2
# 270      Ho-oh     130           2
# 542    Heatran      90           4
# 799  Volcanion     110           6

# %%
# Question 15 (Code Validated)
# Select Slow and Fast pokemons
# Select pokemons that are:
# Very slow → Speed below bottom 5%
# Very fast → Speed above top 95%
# Store results in slow_fast_df.

bottom_5 = df['Speed'].quantile(.05)
top_5 = df["Speed"].quantile(.95)
(bottom_5,top_5)
# Out:
# (np.float64(25.0), np.float64(115.0))

# %%
ax = df["Speed"].plot(kind='hist',figsize=(10,5),bins =100)
ax.axvline(df['Speed'].quantile(.05),color='red')
ax.axvline(df['Speed'].quantile(.95),color="red")

# %%
df.query("Speed < @bottom_5 or Speed > @top_5")
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 19    15  BeedrillMega Beedrill       Bug  Poison    495   65     150
# 23    18    PidgeotMega Pidgeot    Normal  Flying    579   83      80
# 44    39             Jigglypuff    Normal   Fairy    270  115      45
# 56    51                Dugtrio    Ground     NaN    405   35      80
# 70    65               Alakazam   Psychic     NaN    500   55      50
# ..   ...                    ...       ...     ...    ...  ...     ...
# 726  658               Greninja     Water    Dark    530   72      95
# 731  663             Talonflame      Fire  Flying    499   78      81
# 752  682               Spritzee     Fairy     NaN    341   78      52
# 771  701               Hawlucha  Fighting  Flying    500   78      92
# 791  715                Noivern    Flying  Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 19        40       15       80    145           1      False
# ...

# %%
slow_fast_df=df.loc[(df['Speed'] < bottom_5) | (df['Speed'] > top_5)]
slow_fast_df
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 19    15  BeedrillMega Beedrill       Bug  Poison    495   65     150
# 23    18    PidgeotMega Pidgeot    Normal  Flying    579   83      80
# 44    39             Jigglypuff    Normal   Fairy    270  115      45
# 56    51                Dugtrio    Ground     NaN    405   35      80
# 70    65               Alakazam   Psychic     NaN    500   55      50
# ..   ...                    ...       ...     ...    ...  ...     ...
# 726  658               Greninja     Water    Dark    530   72      95
# 731  663             Talonflame      Fire  Flying    499   78      81
# 752  682               Spritzee     Fairy     NaN    341   78      52
# 771  701               Hawlucha  Fighting  Flying    500   78      92
# 791  715                Noivern    Flying  Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 19        40       15       80    145           1      False
# ...

# %%
# Question 16
# Find the Ultra Powerful Legendary Pokemon
# Look at the scatter plot correlating Defense to Attack.
# What's the name of the pokemon indicated by the red arrow?
df.loc[df["Legendary"]].sort_values(by=['Attack','Defense'],ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386     DeoxysAttack Forme  Psychic       NaN    600   50     180
# 711  646     KyuremBlack Kyurem   Dragon       Ice    700  125     170
# ..   ...                    ...      ...       ...    ...  ...     ...
# 416  379              Registeel    Steel       NaN    580   80      75
# 537  480                   Uxie  Psychic       NaN    580   75      75
# 264  245                Suicune    Water       NaN    580  100      75
# 430  386    DeoxysDefense Forme  Psychic       NaN    600   50      70
# 415  378                 Regice      Ice       NaN    580   80      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
fig,ax = plt.subplots(figsize=(14,7))
sns.scatterplot(data=df,x="Defense",y="Attack",hue="Legendary",ax=ax)
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>
