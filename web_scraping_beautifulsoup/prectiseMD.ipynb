# %%
import requests
from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com/"
html = requests.get(url).text

soup = BeautifulSoup(html, "html.parser")
# Extract all quotes + authors
quotes=soup.find_all("div",class_="quote")
for q in quotes:
    text = q.find("span", class_="text").text
    author = q.find("small", class_="author").text
    print(text, "-", author)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison
# ...

# %%
links=soup.find_all("a")
for link in links:
    print(link.get("href"))
# Out:
# /
# /login
# /author/Albert-Einstein
# /tag/change/page/1/
# /tag/deep-thoughts/page/1/
# /tag/thinking/page/1/
# /tag/world/page/1/
# /author/J-K-Rowling
# /tag/abilities/page/1/
# /tag/choices/page/1/
# /author/Albert-Einstein
# /tag/inspirational/page/1/
# /tag/life/page/1/
# /tag/live/page/1/
# /tag/miracle/page/1/
# /tag/miracles/page/1/
# /author/Jane-Austen
# /tag/aliteracy/page/1/
# /tag/books/page/1/
# /tag/classic/page/1/
# /tag/humor/page/1/
# /author/Marilyn-Monroe
# /tag/be-yourself/page/1/
# /tag/inspirational/page/1/
# /author/Albert-Einstein
# /tag/adulthood/page/1/
# /tag/success/page/1/
# /tag/value/page/1/
# /author/Andre-Gide
# /tag/life/page/1/
# /tag/love/page/1/
# /author/Thomas-A-Edison
# /tag/edison/page/1/
# /tag/failure/page/1/
# /tag/inspirational/page/1/
# /tag/paraphrased/page/1/
# /author/Eleanor-Roosevelt
# /tag/misattributed-eleanor-roosevelt/page/1/
# /author/Steve-Martin
# /tag/humor/page/1/
# /tag/obvious/page/1/
# /tag/simile/page/1/
# /page/2/
# ...

# %%
## .parent,.children,.next_sibling,.previous_sibling  PAge navigation

# %%
qua=soup.find("span",class_="text")
print(qua.previous_sibling)

# %%
# Q1: Website ka title extract karo
# Q2: Sare quotes aur authors extract karo
# Q3: Sare tags (keywords) extract karo
# Q4: Website ke sare hyperlinks nikaalo
# Q5: Ek image ka src URL find karo
# # Q6: Multiple pages scrape karke CSV file me save karo
title=soup.title.text
print(title)

quote=soup.find_all("div",class_="quote")
for q in quote:
    text=q.find("span",class_="text").text
    author=q.find("small",class_="author").text
    print(text, "-", author)

print("------Tags--------")
tags=soup.find_all("div",class_="tags")
for tag in tags:
    t=tag.select(".tag")
    for tt in t:
        print(tt.text)
print("----------HyperLinks----------")
links=soup.find_all("a")
for link in links:
    print(link.get("href"))
image=soup.find("img")
# Out:
# Quotes to Scrape
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison
# ...

# %%
two=soup.find_all("div", class_="quote", limit=2)
h=soup.find_all(["h1", "h2", "h3"])
print(h)
# Out:
# [<h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>, <h2>Top Ten tags</h2>]

# %%
aa=soup.select(".text")
aaa=soup.select("span.text")
print(aaa)
#Tag inside tag
tit=soup.select("div.quote span.tag")
print(tit)
#Select_one
quote = soup.select_one("span.text")
print(quote.text)
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>, <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>, <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>, <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>, <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>, <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>, <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</s
# ...

# %%
al=soup.select(".tag.item")
print(al)
# Out:
# []

# %%
h=soup.select("a[href='/login']")
hh=soup.select("a[href*='page']")
hhh=soup.select("a[href^='http']")
soup.select("img[src$='.jpg']")
soup.select("img[src$='.jpg']")
print(hhh)
# Out:
# [<a href="https://www.goodreads.com/quotes">GoodReads.com</a>, <a class="zyte" href="https://www.zyte.com">Zyte</a>]

# %%
#extract all tag keywords
tag=soup.select("div.quote .tag")
for t in tag:
    print(t.text)
l=soup.select("a[href]")
print(l)
# Out:
# change
# deep-thoughts
# thinking
# world
# abilities
# choices
# inspirational
# life
# live
# miracle
# miracles
# aliteracy
# books
# classic
# humor
# be-yourself
# inspirational
# adulthood
# success
# value
# life
# love
# edison
# failure
# inspirational
# paraphrased
# misattributed-eleanor-roosevelt
# humor
# obvious
# simile
# ...

# %%
# Q1

# Sare authors ko CSS selector se print karo.
# Hint: "small.author"

author=soup.select("div small.author")
for a in author:
    print(a.text)

# Q2

# Pehle quote ka text select_one() se print karo.
q=soup.select_one("span.text")
print(q.text)

# Q3

# Sare tags (keywords) "div.quote .tag" ise find karo.
q=soup.select("div.quote .tag")
if q:
    for element in q:
        print(element.get_text())


# Q4

# Sare links extract karo jinke href "page" se contain karte hain.
# Hint: [href*='page']
a=soup.select("a[href*='page']")
print(a)
# Q5

# Images extract karo jinka src ".jpg" se end hota ho.
# # Hint: img[src$='.jpg']
a=soup.select("img[src$='.jpg']")
print(a)
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# change
# deep-thoughts
# thinking
# world
# abilities
# choices
# inspirational
# life
# live
# miracle
# miracles
# aliteracy
# books
# classic
# humor
# be-yourself
# inspirational
# adulthood
# success
# value
# life
# love
# edison
# failure
# inspirational
# paraphrased
# misattributed-eleanor-roosevelt
# humor
# obvious
# simile
# ...

# %%
quote = soup.find("span", class_="text")
for q in quote.parent:
    print(q.name)
# Out:
# None
# span
# None
# span
# None
# div
# None

# %%
qq=soup.find("div",class_="quote")
for q in qq.children:
    print(q)
# Out:
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#
#
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
#
#
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>

# %%
# Q1 Pehli quote find karo → uska parent print karo.
quote=soup.find("span",class_="text")
print(quote.parent)
# Q2 Pehli quote find karo → uske saare sibling tags print karo.
quote=soup.find("span",class_="text")
for q in quote.parent:
    print(q.name)
# Q3 Pehle <div class='quote'> ke children print karo.
for q in quote.children:
    print(q.name)
#Q4 Pehli quote se author tak navigate karo (parent → author).
quote = soup.find("div", class_="quote")
author_small = quote.contents[3].find("small")
print(author_small.text)


# Q5
# # Sare tags (keywords) navigation ke through find karo.
quout=soup.find("div",class_="quote")
author=soup.find("small",class_="author")
author_p=author.parent
tags_div = author_p.find_next_sibling("div")
print(tags)
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>
# None
# span
# None
# span
# None
# div
# None
# None
# Albert Einstein
# [<div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# ...
